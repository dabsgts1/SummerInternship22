# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.tree import DecisionTreeRegressor

# %%
# save filepath to variable for easier access
home_data_file_path = 'train.csv'

# read the data and store data in DataFrame titled home_data
home_data = pd.read_csv(home_data_file_path) 

# print a summary of the data in Melbourne data
home_data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
# printing all columns
home_data.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
# ask for features the user wants considered
features = input('Enter features to be considered separated by a comma: ')
ft_list = []
features = features.replace(' ','')
features = features.replace("'","")

# converting input to a list and confirming that each feature is valid
for feature in features.split(','):
    if feature in home_data.columns:
        ft_list.append(feature)
        
# 'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',        'SaleCondition'
print(ft_list)

train_X = home_data[ft_list] # list of features from our training set train.csv
train_X = pd.get_dummies(train_X)
train_y = home_data.SalePrice # corresponding Sale Price

test_path = 'test.csv'
test_data = pd.read_csv(test_path) 
test_X = test_data[ft_list] # list of features from our testing set test.csv
test_X = pd.get_dummies(test_X)
# Out:
# Enter features to be considered separated by a comma: 'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',        'SaleCondition'
# ['Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType', 'SaleCondition']

# %%
pos = 0
for col in train_X.columns:
    if not col in test_X.columns:
        test_X.insert(pos, col, 0)
    pos = pos + 1

# %%
train_X.columns
# Out:
# Index(['MiscVal', 'MoSold', 'YrSold', 'Fence_GdPrv', 'Fence_GdWo',
#        'Fence_MnPrv', 'Fence_MnWw', 'MiscFeature_Gar2', 'MiscFeature_Othr',
#        'MiscFeature_Shed', 'MiscFeature_TenC', 'SaleType_COD', 'SaleType_CWD',
#        'SaleType_Con', 'SaleType_ConLD', 'SaleType_ConLI', 'SaleType_ConLw',
#        'SaleType_New', 'SaleType_Oth', 'SaleType_WD', 'SaleCondition_Abnorml',
#        'SaleCondition_AdjLand', 'SaleCondition_Alloca', 'SaleCondition_Family',
#        'SaleCondition_Normal', 'SaleCondition_Partial'],
#       dtype='object')

# %%
test_X.columns
# Out:
# Index(['MiscVal', 'MoSold', 'YrSold', 'Fence_GdPrv', 'Fence_GdWo',
#        'Fence_MnPrv', 'Fence_MnWw', 'MiscFeature_Gar2', 'MiscFeature_Othr',
#        'MiscFeature_Shed', 'MiscFeature_TenC', 'SaleType_COD', 'SaleType_CWD',
#        'SaleType_Con', 'SaleType_ConLD', 'SaleType_ConLI', 'SaleType_ConLw',
#        'SaleType_New', 'SaleType_Oth', 'SaleType_WD', 'SaleCondition_Abnorml',
#        'SaleCondition_AdjLand', 'SaleCondition_Alloca', 'SaleCondition_Family',
#        'SaleCondition_Normal', 'SaleCondition_Partial'],
#       dtype='object')

# %%
home_model = DecisionTreeRegressor(random_state=1)
home_model.fit(train_X, train_y)


print("Making predictions for the following houses:")
test_X
# Out:
# Making predictions for the following houses:
#       MiscVal  MoSold  YrSold  Fence_GdPrv  Fence_GdWo  Fence_MnPrv  \
# 0           0       6    2010            0           0            1
# 1       12500       6    2010            0           0            0
# 2           0       3    2010            0           0            1
# 3           0       6    2010            0           0            0
# 4           0       1    2010            0           0            0
# ...       ...     ...     ...          ...         ...          ...
# 1454        0       6    2006            0           0            0
# 1455        0       4    2006            0           0            0
# 1456        0       9    2006            0           0            0
# 1457      700       7    2006            0           0            1
# 1458        0      11    2006            0           0            0
#
#       Fence_MnWw  MiscFeature_Gar2  MiscFeature_Othr  MiscFeature_Shed  ...  \
# ...

# %%
print("The predictions are")
home_predictions = home_model.predict(test_X)
home_predictions
# Out:
# The predictions are
# array([151333.33333333, 151500.        , 158000.        , ...,
#        257000.        ,  88000.        , 241943.75      ])

# %%
ind = 1461
df = pd.DataFrame(columns=['Id','SalePrice'])
for price in home_predictions:
    newrow = pd.DataFrame({'Id': [ind], 'SalePrice':[price]})
    df = pd.concat([df, newrow], ignore_index = True)
    ind = ind + 1
    
df
# Out:
#         Id      SalePrice
# 0     1461  151333.333333
# 1     1462       151500.0
# 2     1463       158000.0
# 3     1464  176608.695652
# 4     1465       210075.0
# ...    ...            ...
# 1454  2915       170690.0
# 1455  2916  114050.666667
# 1456  2917       257000.0
# 1457  2918        88000.0
# 1458  2919      241943.75
#
# [1459 rows x 2 columns]

# %%
df.to_csv (r'house_prices.csv', index=False, header=True)
